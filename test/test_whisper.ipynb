# %%
import whisper

model = whisper.load_model('small')
result = model.transcribe('E:\SCY\hololens2_server/test/audio2.wav')
result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import whisper
#       3 model = whisper.load_model('small', device='cuda')
# ----> 4 result = model.transcribe('E:\SCY\hololens2_server/test/audio2.wav')
#       5 result
#
# File d:\Anaconda\envs\hololens2\lib\site-packages\whisper\transcribe.py:122, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, **decode_options)
#     119     decode_options["fp16"] = False
#     121 # Pad 30-seconds of silence to the input audio, for slicing
# --> 122 mel = log_mel_spectrogram(audio, model.dims.n_mels, padding=N_SAMPLES)
#     123 content_frames = mel.shape[-1] - N_FRAMES
#     125 if decode_options.get("language", None) is None:
#
# ...
